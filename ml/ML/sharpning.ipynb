# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
img=cv2.imread('img.jpg')
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
gauss=cv2.GaussianBlur(img, (5,5),0)
sharpened_img=cv2.addWeighted(img, 1.5, gauss, -0.5,0)
plt.subplot(1,2,1), plt.imshow(img), plt.title('Source image'), plt.axis('off')
plt.subplot(1,2,2), plt.imshow(sharpened_img), plt.title('sharped_img'), plt.axis('off')
# Out:
# (<Axes: title={'center': 'sharped_img'}>,
# ...
#  Text(0.5, 1.0, 'sharped_img'),
#  (-0.5, 2559.5, 1706.5, -0.5))

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
#img=cv2.imread('octagone.png')
img=cv2.imread('img.jpg')
k1=np.array([[0,-1,0], [-1,5,-1], [0,-1,0]])
img1=cv2.filter2D (img,-1, k1)
plt.subplot(2,2,1), plt.imshow(img), plt.title('Source'), plt.axis
plt.subplot(2,2,2), plt.imshow(img1), plt.title('Res'), plt.axis
# Out:
# (<Axes: title={'center': 'Res'}>,
# ...
#  Text(0.5, 1.0, 'Res'),
#  <function matplotlib.pyplot.axis(arg=None, /, *, emit=True, **kwargs)>)
